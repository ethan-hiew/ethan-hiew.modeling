# %%
# Import dependecies
import numpy as np
import pandas as pd
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.metrics import fbeta_score

# %%
# Mounting Google Drive and setting path to import data
from google.colab import drive
drive.mount("/content/drive")
path = "drive/MyDrive/HUDK4050 Midterm Project/notebooks/data/"

# Import the cleaned dataset
dropout_df = pd.read_csv(path + "cleaned_data.csv")
# Out:
# Mounted at /content/drive

# %%
dropout_df
# Out:
#        StudentID  Dropout  CohortTerm_x  RegistrationDate  Gender  BirthMonth  \
# 0         285848        0             1          20110808       2           9
# 1         302176        0             1          20110804       1           4
# 2         301803        0             1          20110809       2           4
# 3         302756        0             1          20110823       2           1
# 4         301067        0             1          20110420       1           4
# ...          ...      ...           ...               ...     ...         ...
# 12256     317229        0             1          20160912       2           3
# 12257     325536        0             1          20160427       2           4
# 12258     342013        0             1          20160726       2           4
# 12259     359065        0             1          20160825       1           3
# 12260     359327        0             1          20160912       1           2
#
#        HSDip  HSDipYr  HSGPAUnwtd  HSGPAWtd  ...  \
# 0          1       -1        -1.0        -1  ...
# 1          1       -1        -1.0        -1  ...
# 2          1       -1        -1.0        -1  ...
# 3         -1       -1        -1.0        -1  ...
# 4          1       -1        -1.0        -1  ...
# ...      ...      ...         ...       ...  ...
# 12256      1       -1        -1.0        -1  ...
# 12257      1       -1        -1.0        -1  ...
# 12258      1       -1        -1.0        -1  ...
# 12259      1       -1        -1.0        -1  ...
# 12260      1       -1        -1.0        -1  ...
#
#        Father's Highest Grade Level_Middle School  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               1
# ...                                           ...
# 12256                                           0
# 12257                                           0
# 12258                                           0
# 12259                                           0
# 12260                                           0
#
#        Father's Highest Grade Level_Unknown  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
# ...                                     ...
# 12256                                     0
# 12257                                     0
# 12258                                     0
# 12259                                     0
# 12260                                     1
#
#        Mother's Highest Grade Level_College  \
# 0                                         1
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
# ...                                     ...
# 12256                                     0
# 12257                                     0
# 12258                                     0
# 12259                                     0
# 12260                                     0
#
#        Mother's Highest Grade Level_High School  \
# 0                                             0
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
# ...                                         ...
# 12256                                         1
# 12257                                         0
# 12258                                         1
# 12259                                         1
# 12260                                         0
#
#        Mother's Highest Grade Level_Middle School  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 12256                                           0
# 12257                                           1
# 12258                                           0
# 12259                                           0
# 12260                                           0
#
#        Mother's Highest Grade Level_Unknown  Housing_Off Campus  \
# 0                                         0                   1
# 1                                         0                   1
# 2                                         0                   1
# 3                                         0                   1
# 4                                         0                   1
# ...                                     ...                 ...
# 12256                                     0                   1
# 12257                                     0                   0
# 12258                                     0                   1
# 12259                                     0                   1
# 12260                                     1                   0
#
#        Housing_On Campus Housing  Housing_With Parent  Race
# 0                              0                    0     6
# 1                              0                    0     6
# 2                              0                    0     6
# 3                              0                    0     6
# 4                              0                    0     6
# ...                          ...                  ...   ...
# 12256                          0                    0     1
# 12257                          0                    1     6
# 12258                          0                    0     6
# 12259                          0                    0     6
# 12260                          0                    1     6
#
# [12261 rows x 54 columns]

# %%
# Set the faetures and target variable for the dataset
X = dropout_df.drop("Dropout", axis = 1)
y = dropout_df["Dropout"]

# Split the data into training and test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# # Training XGBoost Model

# %%
# Create a XGBoost Classifier object
xgb_classifier = xgb.XGBClassifier()

# Training the XGBoost Classifier on the cleaned data
xgb_classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# Make predictions on the test set
y_pred = xgb_classifier.predict(X_test)

# Calculate F-beta score (beta = 2) for the XGBoost model
fbeta_scored = fbeta_score(y_test, y_pred, beta = 2)

# %%
# Display the F-beta score
print(f"XGBoost Classifier F-beta Score (beta = 2): {fbeta_scored:.5f}")
# Out:
# XGBoost Classifier F-beta Score (beta = 2): 0.76492

# %% [markdown]
# # Fitting Logistic Regression Model to Kaggletest Data

# %%
# Import kaggle test data
kaggletest_df = pd.read_csv(path + "cleaned_kaggletest.csv")

kaggletest_df
# Out:
#      StudentID  CohortTerm_x  RegistrationDate  Gender  BirthMonth  HSDip  \
# 0       344883             1          20150611       2          11      1
# 1       298782             1          20110516       1          11      1
# 2       311983             1          20120522       1          10      1
# 3       346945             1          20150528       2           3      1
# 4       313391             1          20120611       1          11      1
# ..         ...           ...               ...     ...         ...    ...
# 995     310102             1          20120703       1           7      1
# 996     329407             1          20140616       2          10      1
# 997     323071             1          20130813       1           8      1
# 998     356228             1          20160629       2           8      1
# 999     320283             1          20130416       1          10      1
#
#      HSDipYr  HSGPAUnwtd  HSGPAWtd  FirstGen  ...  \
# 0       2015        2.62        -1        -1  ...
# 1       2011        3.60        -1        -1  ...
# 2       2012        3.14        -1        -1  ...
# 3       2015        3.96        -1        -1  ...
# 4         -1       -1.00        -1        -1  ...
# ..       ...         ...       ...       ...  ...
# 995       -1       -1.00        -1        -1  ...
# 996       -1       -1.00        -1        -1  ...
# 997       -1       -1.00        -1        -1  ...
# 998       -1       -1.00        -1        -1  ...
# 999       -1       -1.00        -1        -1  ...
#
#      Father's Highest Grade Level_Middle School  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 995                                           0
# 996                                           0
# 997                                           1
# 998                                           0
# 999                                           1
#
#      Father's Highest Grade Level_Unknown  \
# 0                                       0
# 1                                       0
# 2                                       1
# 3                                       0
# 4                                       0
# ..                                    ...
# 995                                     0
# 996                                     0
# 997                                     0
# 998                                     0
# 999                                     0
#
#      Mother's Highest Grade Level_College  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ..                                    ...
# 995                                     0
# 996                                     1
# 997                                     0
# 998                                     1
# 999                                     0
#
#      Mother's Highest Grade Level_High School  \
# 0                                           0
# 1                                           1
# 2                                           0
# 3                                           0
# 4                                           1
# ..                                        ...
# 995                                         1
# 996                                         0
# 997                                         0
# 998                                         0
# 999                                         0
#
#      Mother's Highest Grade Level_Middle School  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 995                                           0
# 996                                           0
# 997                                           1
# 998                                           0
# 999                                           1
#
#      Mother's Highest Grade Level_Unknown  Housing_Off Campus  \
# 0                                       1                   0
# 1                                       0                   0
# 2                                       1                   0
# 3                                       1                   0
# 4                                       0                   0
# ..                                    ...                 ...
# 995                                     0                   1
# 996                                     0                   1
# 997                                     0                   1
# 998                                     0                   1
# 999                                     0                   1
#
#      Housing_On Campus Housing  Housing_With Parent  Race
# 0                            1                    0     4
# 1                            0                    1     3
# 2                            0                    1     1
# 3                            0                    1     4
# 4                            0                    1     6
# ..                         ...                  ...   ...
# 995                          0                    0     1
# 996                          0                    0     1
# 997                          0                    0     1
# 998                          0                    0     1
# 999                          0                    0     4
#
# [1000 rows x 53 columns]

# %%
# Make predictions on the kaggletest DataFrame using Logistic Regression model
y_pred = xgb_classifier.predict(kaggletest_df)

# Create a new column in kaggletest DataFrame for predictions
kaggletest_df["Dropout"] = y_pred

# %% [markdown]
# # Create Submission DataFrame and then Export to .csv

# %%
# Splice the kaggletest DataFrame to only include StudentID and Dropout label
submission_df = kaggletest_df[["StudentID", "Dropout"]]

submission_df
# Out:
#      StudentID  Dropout
# 0       344883        0
# 1       298782        1
# 2       311983        0
# 3       346945        0
# 4       313391        0
# ..         ...      ...
# 995     310102        0
# 996     329407        0
# 997     323071        1
# 998     356228        0
# 999     320283        0
#
# [1000 rows x 2 columns]

# %%
# Export submission DataFrame to submission folder as first Logistic Regression submission
submission_df.to_csv(path + "submissions/xgb_submission_3.csv", index = False)

# %% [markdown]
# # Optimize our XGB Classifier Using Hyperparameter Tuning

# %%
# Import additional dependencies
from xgboost import XGBClassifier

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.preprocessing import StandardScaler

# %%
# Scaling features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Re-instantiate the XGBoost classifier
xgb_classifer = XGBClassifier(use_label_encoder = False, eval_metric = "logloss")

# Defining F-beta score with beta = 2 as scoring metrics for hyperparameter tuning
f2_scorer = make_scorer(fbeta_score, beta = 2)

# %%
# Setting up RandomizedSearchCV for hyperparameter tuning
param_dist = {
    'n_estimators': [100, 200, 300, 400, 500],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'max_depth': [3, 4, 5, 6, 7, 8],
    'min_child_weight': [1, 2, 3, 4],
    'subsample': [0.6, 0.7, 0.8, 0.9],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9]
}
random_search = RandomizedSearchCV(xgb_classifier, param_distributions = param_dist,
                                   n_iter = 50, scoring = f2_scorer, verbose = 3)

# %%
# Fitting the model onto the data
random_search.fit(X_train_scaled, y_train)

# Display the best parameters and the best F-beta score
best_params = random_search.best_params_
best_score = random_search.best_score_

best_params, best_score
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.7;, score=0.797 total time=   5.6s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.7;, score=0.781 total time=   7.7s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.7;, score=0.773 total time=   4.3s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.7;, score=0.785 total time=   4.8s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.7;, score=0.784 total time=   3.1s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=400, subsample=0.7;, score=0.816 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=400, subsample=0.7;, score=0.782 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=400, subsample=0.7;, score=0.771 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=400, subsample=0.7;, score=0.780 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=400, subsample=0.7;, score=0.786 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=8, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.785 total time=   1.6s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=8, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.776 total time=   1.7s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=8, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.765 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=8, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.777 total time=   1.6s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=8, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.787 total time=   4.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.9;, score=0.779 total time=   2.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.9;, score=0.762 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.9;, score=0.769 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.9;, score=0.782 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.9;, score=0.780 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.799 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.779 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.765 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.791 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.787 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.791 total time=   2.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.780 total time=   3.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.765 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.792 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.788 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=8, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.780 total time=   1.7s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=8, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.770 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=8, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.766 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=8, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.792 total time=   1.6s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=8, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.769 total time=   3.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.6;, score=0.782 total time=   3.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.6;, score=0.790 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.6;, score=0.774 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.6;, score=0.782 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.6;, score=0.775 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.9;, score=0.794 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.9;, score=0.777 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.9;, score=0.762 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.9;, score=0.776 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.9;, score=0.786 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.785 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.781 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.775 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.786 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.781 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=8, min_child_weight=4, n_estimators=400, subsample=0.7;, score=0.775 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=8, min_child_weight=4, n_estimators=400, subsample=0.7;, score=0.764 total time=   3.3s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=8, min_child_weight=4, n_estimators=400, subsample=0.7;, score=0.770 total time=   4.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=8, min_child_weight=4, n_estimators=400, subsample=0.7;, score=0.786 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.2, max_depth=8, min_child_weight=4, n_estimators=400, subsample=0.7;, score=0.775 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.783 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.770 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.767 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.780 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.774 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.6;, score=0.778 total time=   3.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.6;, score=0.778 total time=   4.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.6;, score=0.777 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.6;, score=0.799 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.6;, score=0.780 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.769 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.765 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.750 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.753 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.761 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.9;, score=0.787 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.9;, score=0.768 total time=   1.9s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.9;, score=0.767 total time=   4.7s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.9;, score=0.786 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.2, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.9;, score=0.782 total time=   0.9s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=8, min_child_weight=4, n_estimators=500, subsample=0.6;, score=0.780 total time=   1.4s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=8, min_child_weight=4, n_estimators=500, subsample=0.6;, score=0.786 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=8, min_child_weight=4, n_estimators=500, subsample=0.6;, score=0.775 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=8, min_child_weight=4, n_estimators=500, subsample=0.6;, score=0.784 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=8, min_child_weight=4, n_estimators=500, subsample=0.6;, score=0.780 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.6;, score=0.789 total time=   5.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.6;, score=0.767 total time=   3.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.6;, score=0.765 total time=   1.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.6;, score=0.789 total time=   1.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=400, subsample=0.6;, score=0.778 total time=   1.8s
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.7;, score=0.794 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.7;, score=0.780 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.7;, score=0.759 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.7;, score=0.774 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.7;, score=0.785 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.802 total time=   2.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.773 total time=   4.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.777 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.786 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.6;, score=0.788 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.6;, score=0.781 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.6;, score=0.776 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.6;, score=0.764 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.6;, score=0.791 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.6;, score=0.775 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.6;, score=0.783 total time=   3.8s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.6;, score=0.781 total time=   2.0s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.6;, score=0.775 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.6;, score=0.785 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.6;, score=0.791 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8;, score=0.792 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8;, score=0.768 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8;, score=0.768 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8;, score=0.774 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=4, min_child_weight=2, n_estimators=500, subsample=0.8;, score=0.777 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9;, score=0.755 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9;, score=0.753 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9;, score=0.727 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9;, score=0.750 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9;, score=0.747 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=4, n_estimators=400, subsample=0.8;, score=0.790 total time=   1.4s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=4, n_estimators=400, subsample=0.8;, score=0.776 total time=   2.5s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=4, n_estimators=400, subsample=0.8;, score=0.777 total time=   5.2s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=4, n_estimators=400, subsample=0.8;, score=0.791 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=4, n_estimators=400, subsample=0.8;, score=0.782 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.7;, score=0.804 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.7;, score=0.775 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.7;, score=0.771 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.7;, score=0.786 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.7;, score=0.789 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7;, score=0.791 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7;, score=0.777 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7;, score=0.763 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7;, score=0.792 total time=   1.8s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7;, score=0.793 total time=   4.1s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.795 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.776 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.766 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.784 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.785 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.803 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.784 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.772 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.784 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.8;, score=0.786 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.9;, score=0.747 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.9;, score=0.739 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.9;, score=0.724 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.9;, score=0.743 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.9;, score=0.743 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.779 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.761 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.762 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.762 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.777 total time=   5.6s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6;, score=0.791 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6;, score=0.781 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6;, score=0.761 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6;, score=0.770 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6;, score=0.781 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=300, subsample=0.8;, score=0.753 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=300, subsample=0.8;, score=0.754 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=300, subsample=0.8;, score=0.736 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=300, subsample=0.8;, score=0.739 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=300, subsample=0.8;, score=0.751 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.9;, score=0.783 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.9;, score=0.767 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.9;, score=0.763 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.9;, score=0.769 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.9;, score=0.784 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=300, subsample=0.7;, score=0.797 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=300, subsample=0.7;, score=0.773 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=300, subsample=0.7;, score=0.771 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=300, subsample=0.7;, score=0.780 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=300, subsample=0.7;, score=0.789 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.784 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.765 total time=   2.7s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.758 total time=   4.4s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.764 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=0.784 total time=   5.0s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.8;, score=0.795 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.8;, score=0.771 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.8;, score=0.767 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.8;, score=0.779 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.8;, score=0.780 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9;, score=0.608 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9;, score=0.593 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9;, score=0.709 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9;, score=0.614 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9;, score=0.646 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.784 total time=   2.7s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.776 total time=   2.4s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.765 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.779 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.794 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=0.802 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=0.780 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=0.774 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=0.790 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=0.787 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8;, score=0.748 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8;, score=0.751 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8;, score=0.733 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8;, score=0.735 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.8;, score=0.741 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.8;, score=0.791 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.8;, score=0.774 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.8;, score=0.782 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.8;, score=0.773 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.8;, score=0.774 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9;, score=0.789 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9;, score=0.780 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9;, score=0.765 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9;, score=0.768 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9;, score=0.783 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.6;, score=0.620 total time=   1.4s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.6;, score=0.587 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.6;, score=0.710 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.6;, score=0.619 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.6;, score=0.728 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8;, score=0.795 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8;, score=0.775 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8;, score=0.777 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8;, score=0.791 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.8;, score=0.776 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.9;, score=0.802 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.9;, score=0.771 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.9;, score=0.773 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.9;, score=0.783 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.2, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.9;, score=0.781 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.7;, score=0.781 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.7;, score=0.774 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.7;, score=0.752 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.7;, score=0.758 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.7;, score=0.777 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6;, score=0.787 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6;, score=0.766 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6;, score=0.756 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6;, score=0.768 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.6;, score=0.784 total time=   5.7s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.8;, score=0.801 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.8;, score=0.781 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.8;, score=0.768 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.8;, score=0.784 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.8;, score=0.789 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.6;, score=0.788 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.6;, score=0.754 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.6;, score=0.778 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.6;, score=0.775 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.6;, score=0.771 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.7;, score=0.787 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.7;, score=0.772 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.7;, score=0.760 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.7;, score=0.785 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.7;, score=0.783 total time=   2.4s
# ({'subsample': 0.7,
#   'n_estimators': 400,
#   'min_child_weight': 2,
#   'max_depth': 3,
#   'learning_rate': 0.2,
#   'colsample_bytree': 0.6},
#  0.7869556390357294)

# %% [markdown]
# ## Training Optimal XGB Classifier

# %%
# Instantiate the optimal XGBoost classifier with optimal hyperparameters
xgb_model = XGBClassifier(
    subsample = 0.7,
    n_estimators = 400,
    min_child_weight = 2,
    max_depth = 3,
    learning_rate = 0.2,
    colsample_bytree = 0.6,
    use_label_encoder = False,
    eval_metric = "logloss"
)

# Fit the model to the training data
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=2, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=400,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
# Make predictions using the trained model
y_pred = xgb_model.predict(X_test)

# Calculate the F-beta score with beta = 2
f2_score = fbeta_score(y_test, y_pred, beta = 2)
f2_score
# Out:
# 0.7766785939802148

# %% [markdown]
# # Fitting Logistic Regression Model to Kaggletest Data

# %%
# Import kaggle test data
kaggletest_df = pd.read_csv(path + "cleaned_kaggletest.csv")

kaggletest_df
# Out:
#      StudentID  CohortTerm_x  RegistrationDate  Gender  BirthMonth  HSDip  \
# 0       344883             1          20150611       2          11      1
# 1       298782             1          20110516       1          11      1
# 2       311983             1          20120522       1          10      1
# 3       346945             1          20150528       2           3      1
# 4       313391             1          20120611       1          11      1
# ..         ...           ...               ...     ...         ...    ...
# 995     310102             1          20120703       1           7      1
# 996     329407             1          20140616       2          10      1
# 997     323071             1          20130813       1           8      1
# 998     356228             1          20160629       2           8      1
# 999     320283             1          20130416       1          10      1
#
#      HSDipYr  HSGPAUnwtd  HSGPAWtd  FirstGen  ...  \
# 0       2015        2.62        -1        -1  ...
# 1       2011        3.60        -1        -1  ...
# 2       2012        3.14        -1        -1  ...
# 3       2015        3.96        -1        -1  ...
# 4         -1       -1.00        -1        -1  ...
# ..       ...         ...       ...       ...  ...
# 995       -1       -1.00        -1        -1  ...
# 996       -1       -1.00        -1        -1  ...
# 997       -1       -1.00        -1        -1  ...
# 998       -1       -1.00        -1        -1  ...
# 999       -1       -1.00        -1        -1  ...
#
#      Father's Highest Grade Level_Middle School  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 995                                           0
# 996                                           0
# 997                                           1
# 998                                           0
# 999                                           1
#
#      Father's Highest Grade Level_Unknown  \
# 0                                       0
# 1                                       0
# 2                                       1
# 3                                       0
# 4                                       0
# ..                                    ...
# 995                                     0
# 996                                     0
# 997                                     0
# 998                                     0
# 999                                     0
#
#      Mother's Highest Grade Level_College  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ..                                    ...
# 995                                     0
# 996                                     1
# 997                                     0
# 998                                     1
# 999                                     0
#
#      Mother's Highest Grade Level_High School  \
# 0                                           0
# 1                                           1
# 2                                           0
# 3                                           0
# 4                                           1
# ..                                        ...
# 995                                         1
# 996                                         0
# 997                                         0
# 998                                         0
# 999                                         0
#
#      Mother's Highest Grade Level_Middle School  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 995                                           0
# 996                                           0
# 997                                           1
# 998                                           0
# 999                                           1
#
#      Mother's Highest Grade Level_Unknown  Housing_Off Campus  \
# 0                                       1                   0
# 1                                       0                   0
# 2                                       1                   0
# 3                                       1                   0
# 4                                       0                   0
# ..                                    ...                 ...
# 995                                     0                   1
# 996                                     0                   1
# 997                                     0                   1
# 998                                     0                   1
# 999                                     0                   1
#
#      Housing_On Campus Housing  Housing_With Parent  Race
# 0                            1                    0     4
# 1                            0                    1     3
# 2                            0                    1     1
# 3                            0                    1     4
# 4                            0                    1     6
# ..                         ...                  ...   ...
# 995                          0                    0     1
# 996                          0                    0     1
# 997                          0                    0     1
# 998                          0                    0     1
# 999                          0                    0     4
#
# [1000 rows x 53 columns]

# %%
# Make predictions on the kaggletest DataFrame using Logistic Regression model
y_pred = xgb_model.predict(kaggletest_df)

# Create a new column in kaggletest DataFrame for predictions
kaggletest_df["Dropout"] = y_pred

# %% [markdown]
# # Create Submission DataFrame and then Export to .csv

# %%
# Splice the kaggletest DataFrame to only include StudentID and Dropout label
submission_df = kaggletest_df[["StudentID", "Dropout"]]
# Out:
#      StudentID  Dropout
# 0       344883        0
# 1       298782        1
# 2       311983        0
# 3       346945        0
# 4       313391        0
# ..         ...      ...
# 995     310102        0
# 996     329407        0
# 997     323071        1
# 998     356228        0
# 999     320283        0
#
# [1000 rows x 2 columns]

# %%
# Export submission DataFrame to submission folder as first Logistic Regression submission
submission_df.to_csv(path + "submissions/xgb_submission_final.csv", index = False)
